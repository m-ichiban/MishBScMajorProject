# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("NESOEmbeddedWindSolar.csv")
print(df.head())

wind_forecast = df["EMBEDDED_WIND_FORECAST"].loc[0:47]
x_val = df["SETTLEMENT_PERIOD"].loc[0:47]
plt.plot(x_val, wind_forecast)
plt.show()
# Out:
#                DATE_GMT  TIME_GMT       SETTLEMENT_DATE  SETTLEMENT_PERIOD  \
# 0  2025-01-01T00:00:00Z  00:30:00  2025-01-01T00:00:00Z                  1
# 1  2025-01-01T00:00:00Z  01:00:00  2025-01-01T00:00:00Z                  2
# 2  2025-01-01T00:00:00Z  01:30:00  2025-01-01T00:00:00Z                  3
# 3  2025-01-01T00:00:00Z  02:00:00  2025-01-01T00:00:00Z                  4
# 4  2025-01-01T00:00:00Z  02:30:00  2025-01-01T00:00:00Z                  5
#
#    EMBEDDED_WIND_FORECAST  EMBEDDED_WIND_CAPACITY  EMBEDDED_SOLAR_FORECAST  \
# 0                    5452                    6606                        0
# 1                    5358                    6606                        0
# 2                    5358                    6606                        0
# 3                    5158                    6606                        0
# 4                    5158                    6606                        0
#
# ...
